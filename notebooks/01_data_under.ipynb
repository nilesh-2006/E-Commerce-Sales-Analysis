# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df = pd.read_csv("../data/raw/superstore.csv",encoding="latin1")
df.head()
# Out:
#    Row ID        Order ID  Order Date   Ship Date       Ship Mode Customer ID  \
# 0       1  CA-2016-152156   11/8/2016  11/11/2016    Second Class    CG-12520
# 1       2  CA-2016-152156   11/8/2016  11/11/2016    Second Class    CG-12520
# 2       3  CA-2016-138688   6/12/2016   6/16/2016    Second Class    DV-13045
# 3       4  US-2015-108966  10/11/2015  10/18/2015  Standard Class    SO-20335
# 4       5  US-2015-108966  10/11/2015  10/18/2015  Standard Class    SO-20335
#
#      Customer Name    Segment        Country             City  ...  \
# 0      Claire Gute   Consumer  United States        Henderson  ...
# 1      Claire Gute   Consumer  United States        Henderson  ...
# 2  Darrin Van Huff  Corporate  United States      Los Angeles  ...
# 3   Sean O'Donnell   Consumer  United States  Fort Lauderdale  ...
# 4   Sean O'Donnell   Consumer  United States  Fort Lauderdale  ...
#
#   Postal Code  Region       Product ID         Category Sub-Category  \
# 0       42420   South  FUR-BO-10001798        Furniture    Bookcases
# 1       42420   South  FUR-CH-10000454        Furniture       Chairs
# 2       90036    West  OFF-LA-10000240  Office Supplies       Labels
# 3       33311   South  FUR-TA-10000577        Furniture       Tables
# 4       33311   South  OFF-ST-10000760  Office Supplies      Storage
#
#                                         Product Name     Sales  Quantity  \
# 0                  Bush Somerset Collection Bookcase  261.9600         2
# 1  Hon Deluxe Fabric Upholstered Stacking Chairs,...  731.9400         3
# 2  Self-Adhesive Address Labels for Typewriters b...   14.6200         2
# 3      Bretford CR4500 Series Slim Rectangular Table  957.5775         5
# 4                     Eldon Fold 'N Roll Cart System   22.3680         2
#
#    Discount    Profit
# 0      0.00   41.9136
# 1      0.00  219.5820
# 2      0.00    6.8714
# 3      0.45 -383.0310
# 4      0.20    2.5164
#
# [5 rows x 21 columns]

# %%
df.shape
# Out:
# (9994, 21)

# %%
df.columns
# Out:
# Index(['Row ID', 'Order ID', 'Order Date', 'Ship Date', 'Ship Mode',
#        'Customer ID', 'Customer Name', 'Segment', 'Country', 'City', 'State',
#        'Postal Code', 'Region', 'Product ID', 'Category', 'Sub-Category',
#        'Product Name', 'Sales', 'Quantity', 'Discount', 'Profit'],
#       dtype='object')

# %%
df.dtypes
# Out:
# Row ID             int64
# Order ID          object
# Order Date        object
# Ship Date         object
# Ship Mode         object
# Customer ID       object
# Customer Name     object
# Segment           object
# Country           object
# City              object
# State             object
# Postal Code        int64
# Region            object
# Product ID        object
# Category          object
# Sub-Category      object
# Product Name      object
# Sales            float64
# Quantity           int64
# Discount         float64
# Profit           float64
# dtype: object

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 9994 entries, 0 to 9993
# Data columns (total 21 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   Row ID         9994 non-null   int64
#  1   Order ID       9994 non-null   object
#  2   Order Date     9994 non-null   object
#  3   Ship Date      9994 non-null   object
#  4   Ship Mode      9994 non-null   object
#  5   Customer ID    9994 non-null   object
#  6   Customer Name  9994 non-null   object
#  7   Segment        9994 non-null   object
#  8   Country        9994 non-null   object
#  9   City           9994 non-null   object
#  10  State          9994 non-null   object
#  11  Postal Code    9994 non-null   int64
#  12  Region         9994 non-null   object
#  13  Product ID     9994 non-null   object
#  14  Category       9994 non-null   object
#  15  Sub-Category   9994 non-null   object
#  16  Product Name   9994 non-null   object
#  17  Sales          9994 non-null   float64
#  18  Quantity       9994 non-null   int64
#  19  Discount       9994 non-null   float64
#  20  Profit         9994 non-null   float64
# dtypes: float64(3), int64(3), object(15)
# memory usage: 1.6+ MB

# %%
df.describe()
# Out:
#             Row ID   Postal Code         Sales     Quantity     Discount  \
# count  9994.000000   9994.000000   9994.000000  9994.000000  9994.000000
# mean   4997.500000  55190.379428    229.858001     3.789574     0.156203
# std    2885.163629  32063.693350    623.245101     2.225110     0.206452
# min       1.000000   1040.000000      0.444000     1.000000     0.000000
# 25%    2499.250000  23223.000000     17.280000     2.000000     0.000000
# 50%    4997.500000  56430.500000     54.490000     3.000000     0.200000
# 75%    7495.750000  90008.000000    209.940000     5.000000     0.200000
# max    9994.000000  99301.000000  22638.480000    14.000000     0.800000
#
#             Profit
# count  9994.000000
# mean     28.656896
# std     234.260108
# min   -6599.978000
# 25%       1.728750
# 50%       8.666500
# 75%      29.364000
# max    8399.976000

# %%
df.isnull().sum()
# Out:
# Row ID           0
# Order ID         0
# Order Date       0
# Ship Date        0
# Ship Mode        0
# Customer ID      0
# Customer Name    0
# Segment          0
# Country          0
# City             0
# State            0
# Postal Code      0
# Region           0
# Product ID       0
# Category         0
# Sub-Category     0
# Product Name     0
# Sales            0
# Quantity         0
# Discount         0
# Profit           0
# dtype: int64

# %%
df.duplicated().sum()
# Out:
# np.int64(0)

# %% [markdown]
# # Unique Values

# %%
df["Category"].unique()
# Out:
# array(['Furniture', 'Office Supplies', 'Technology'], dtype=object)

# %%
df["Region"].unique()
# Out:
# array(['South', 'West', 'Central', 'East'], dtype=object)

# %%
df["Segment"].unique()
# Out:
# array(['Consumer', 'Corporate', 'Home Office'], dtype=object)

# %% [markdown]
# # Frequency Count

# %%
df["Category"].value_counts()
# Out:
# Category
# Office Supplies    6026
# Furniture          2121
# Technology         1847
# Name: count, dtype: int64

# %%
df["Region"].value_counts()
# Out:
# Region
# West       3203
# East       2848
# Central    2323
# South      1620
# Name: count, dtype: int64

# %%
df["Segment"].value_counts()
# Out:
# Segment
# Consumer       5191
# Corporate      3020
# Home Office    1783
# Name: count, dtype: int64

# %% [markdown]
# # Numerical Columns

# %%
df.select_dtypes(include="number").columns
# Out:
# Index(['Row ID', 'Postal Code', 'Sales', 'Quantity', 'Discount', 'Profit'], dtype='object')

# %% [markdown]
# # Categorical Columns

# %%
df.select_dtypes(include="object").columns
# Out:
# Index(['Order ID', 'Order Date', 'Ship Date', 'Ship Mode', 'Customer ID',
#        'Customer Name', 'Segment', 'Country', 'City', 'State', 'Region',
#        'Product ID', 'Category', 'Sub-Category', 'Product Name'],
#       dtype='object')

# %% [markdown]
# # Memory usage

# %%
df.memory_usage()
# Out:
# Index              132
# Row ID           79952
# Order ID         79952
# Order Date       79952
# Ship Date        79952
# Ship Mode        79952
# Customer ID      79952
# Customer Name    79952
# Segment          79952
# Country          79952
# City             79952
# State            79952
# Postal Code      79952
# Region           79952
# Product ID       79952
# Category         79952
# Sub-Category     79952
# Product Name     79952
# Sales            79952
# Quantity         79952
# Discount         79952
# Profit           79952
# dtype: int64

# %%
df.sample(5)
# Out:
#       Row ID        Order ID Order Date  Ship Date       Ship Mode  \
# 1329    1330  CA-2016-142762  5/23/2016  5/27/2016  Standard Class
# 658      659  US-2016-156097  9/19/2016  9/19/2016        Same Day
# 5897    5898  CA-2016-167682   4/3/2016   4/9/2016  Standard Class
# 3278    3279  CA-2014-102988   4/5/2014   4/9/2014    Second Class
# 7102    7103  CA-2014-117478  9/21/2014  9/24/2014     First Class
#
#      Customer ID       Customer Name      Segment        Country  \
# 1329    LD-17005      Lisa DeCherney     Consumer  United States
# 658     EH-14125   Eugene Hildebrand  Home Office  United States
# 5897    ZD-21925  Zuschuss Donatelli     Consumer  United States
# 3278    GM-14695        Greg Maxwell    Corporate  United States
# 7102    LH-16750        Larry Hughes     Consumer  United States
#
#                City  ... Postal Code   Region       Product ID  \
# 1329  San Francisco  ...       94109     West  FUR-FU-10003691
# 658          Aurora  ...       60505  Central  OFF-BI-10004654
# 5897       Richmond  ...       47374  Central  FUR-FU-10003799
# 3278     Alexandria  ...       22304    South  OFF-PA-10003349
# 7102   Philadelphia  ...       19140     East  OFF-BI-10000050
#
#              Category Sub-Category  \
# 1329        Furniture  Furnishings
# 658   Office Supplies      Binders
# 5897        Furniture  Furnishings
# 3278  Office Supplies        Paper
# 7102  Office Supplies      Binders
#
#                                            Product Name   Sales  Quantity  \
# 1329         Eldon Image Series Desk Accessories, Ebony  37.050         3
# 658   Avery Binding System Hidden Tab Executive Styl...   2.308         2
# 5897                     Seth Thomas 13 1/2" Wall Clock  71.120         4
# 3278                                         Xerox 1957  12.960         2
# 7102  Angle-D Binders with Locking Rings, Label Holders   6.570         3
#
#       Discount   Profit
# 1329       0.0  16.3020
# 658        0.8  -3.4620
# 5897       0.0  22.0472
# 3278       0.0   6.3504
# 7102       0.7  -5.0370
#
# [5 rows x 21 columns]

# %% [markdown]
# # Dataset Overview
#
# Dataset Name : Superstore
#
# Business Domain : E-Commerce
#
# Rows : 9994
#
# Columns : 21
#
# Source : Kaggle
#
# Purpose :
# Analyze Sales, Profit, Customers, Products and Regions.

# %% [markdown]
# ## Business Questions
#
# 1. Which region has the highest sales?
#
# 2. Which category generates the highest profit?
#
# 3. Who are the top customers?
#
# 4. Which products sell the most?
#
# 5. Which states generate the highest revenue?
#
# 6. Does discount reduce profit?
#
# 7. Which month has the highest sales?
#
# 8. Which segment contributes the highest revenue?

# %% [markdown]
# # # Conclusion
#
# • Dataset contains 9,994 records.
#
# • Dataset has 21 columns.
#
# • It contains sales, customer, product and regional information.
#
# • Date columns are currently stored as object type.
#
# • Dataset is ready for data cleaning in the next notebook.
#
# • Next Step → Data Cleaning
